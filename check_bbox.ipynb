# %%
import os
import json
from glob import glob
from pathlib import Path
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
want = 'ja'
nation_dict = {
    'vi': 'vietnamese_receipt',
    'th': 'thai_receipt',
    'zh': 'chinese_receipt',
    'ja': 'japanese_receipt',
}

# %%
with open(os.path.join(os.path.join('./data', nation_dict[want]),'ufo/train.json')) as f:
    json_data=json.load(f)['images']
# print(json_data.keys())
img_names = sorted(list(json_data.keys()))
# len(img_names)

# %%
i=37

# %%
fig, ax = plt.subplots(1,2,figsize=(12,7))
print('count =',i,img_names[i])
ax[0].imshow(Image.open(os.path.join(os.path.join(os.path.join('./data', nation_dict[want]), 'img/train'), img_names[i])))
ax[1].imshow(Image.open(os.path.join(os.path.join(os.path.join('./data', nation_dict[want]), 'img/train'), img_names[i])))
for num in json_data[img_names[i]]['words'].keys():
    points = json_data[img_names[i]]['words'][num]['points']
    poly = patches.Polygon(points, linewidth=1, edgecolor='r', facecolor='none')
    ax[0].add_patch(poly)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[1].set_xticks([])
ax[1].set_yticks([])
plt.show()
i+=1
# Out:
# count = 37 extractor.ja.in_house.appen_000317_page0001.jpg

# %%
for num in list(json_data[img_names[i-1]]['words']):
    tmp = json_data[img_names[i-1]]['words'][num]['transcription']
    print(num, tmp)
# Out:
# 0001 肉汁餃子制作所
# 0002 餃
# 0003 ダンダダン酒場
# 0004
# 0005 新宿店
# 0006 ダンダダン酒場
# 0007
# 0008 東京都新宿区歌舞伎町1-6-14
# 0009 東通ビ
# 0010 ル1F
# 0011 TEL
# 0012 03-6233-8343
# 0013
# 0014 2020年6月5日
# 0015 19時36分
# 0016 日時
# 0017 :
# 0018 人数
# 0019 :
# 0020 2名様
# 0021 卓番
# 0022 :
# 0023 27
# 0024 伝票No
# 0025 :
# 0026 20200605013
# 0027
# 0028 ◎ご注文内容(税込)◎
# 0029 焼き餃子
# 0030 (460)
# 0031 @2
# 0032 1,012
# 0033 生ビール(480)
# 0034 @2
# 0035 1,056
# 0036 柚子キャベツ
# 0037 (380)
# 0038 418
# 0039 ハイボール
# 0040 (460)
# 0041 @4
# 0042 2,024
# 0043 イカの塩辛
# 0044 (380)
# 0045 418
# 0046 チャーシュー
# 0047 (480)
# 0048 528
# 0049 ジャスミン茶
# 0050 (180)
# 0051 198
# 0052
# 0053 合計金額:
# 0054 5,654円
# 0055 (10%対象
# 0056 5,654円)
# 0057 消費税:
# 0058 514円
# 0059 (10%
# 0060 514円)
# 0061 受領金額:
# 0062 6,060円
# 0063 お釣り:
# 0064 406円
# 0065
# 0066 *:軽減税率(8%)適用商品
# 0067
# 0068 ご来店ありがとうございました!
# 0069 またのご利用をお待ちしてます
# 0070 担当:松尾一哉

# %%
num='0007'

fig, ax = plt.subplots(1,1,figsize=[7,7])
ax.imshow(Image.open(os.path.join(os.path.join(os.path.join('./data', nation_dict[want]), 'img/train'), img_names[i-1])))
points = json_data[img_names[i-1]]['words'][num]['points']
poly = patches.Polygon(points, linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(poly)
plt.show()
