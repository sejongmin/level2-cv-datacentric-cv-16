# %%
import os
import json
from glob import glob
from pathlib import Path
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
want = 'ja'
nation_dict = {
    'vi': 'vietnamese_receipt',
    'th': 'thai_receipt',
    'zh': 'chinese_receipt',
    'ja': 'japanese_receipt',
}

# %%
with open(os.path.join(os.path.join('./data', nation_dict[want]),'ufo/train.json')) as f:
    json_data=json.load(f)['images']
# print(json_data.keys())
img_names = sorted(list(json_data.keys()))
# len(img_names)

# %%
i=32

# %%
fig, ax = plt.subplots(1,2,figsize=(12,7))
print('count =',i,img_names[i])
ax[0].imshow(Image.open(os.path.join(os.path.join(os.path.join('./data', nation_dict[want]), 'img/train'), img_names[i])))
ax[1].imshow(Image.open(os.path.join(os.path.join(os.path.join('./data', nation_dict[want]), 'img/train'), img_names[i])))
for num in json_data[img_names[i]]['words'].keys():
    points = json_data[img_names[i]]['words'][num]['points']
    x1, y1 = points[0]
    x2, y2 = points[2]
    # rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=1, edgecolor='r', facecolor='none')
    poly = patches.Polygon(points, linewidth=1, edgecolor='r', facecolor='none')
    ax[0].add_patch(poly)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[1].set_xticks([])
ax[1].set_yticks([])
plt.show()
i+=1
# Out:
# count = 32 extractor.ja.in_house.appen_000264_page0001.jpg

# %%
찾는거 = None
lst=[]
for num in list(json_data[img_names[i-1]]['words']):
    tmp = json_data[img_names[i-1]]['words'][num]['transcription']
    print(num, tmp)
    if tmp == None or len(tmp) == 0:
        continue
    lst.append(num)
if lst:
    print(*lst)
# Out:
# 0001 銀座
# 0002 緑
# 0003 None
# 0004 領
# 0005 収
# 0006 証
# 0007 川崎市麻生区麻生1-4-1
# 0008 B1F
# 0009 044-965-3048
# 0010 2021年07月15日(木)
# 0011 14:04
# 0012 毎度ありがとうございます
# 0013 またのご来店お待ちしています
# 0014
# 0015 美味シソ唐揚げ
# 0016 002320
# 0017 ソ
# 0018 ※
# 0019 1点
# 0020 433
# 0021 ¥433
# 0022 (本体価格
# 0023 ¥401)
# 0024 買上点数
# 0025 1
# 0026 小計
# 0027 ¥433
# 0028 ※印は軽減税率対象商品
# 0029
# 0030 合計
# 0031 ¥433
# 0032 (含む消費税等
# 0033 ¥32)
# 0034 [10%対象
# 0035 ¥0]
# 0036 (含む消費税等
# 0037 ¥0)
# 0038 [
# 0039 8%対象
# 0040 ¥433]
# 0041 (含む消費税等
# 0042 ¥32)
# 0043 ポイント支払
# 0044 ¥33
# 0045 現金
# 0046 ¥1,
# 0047 000
# 0048 お釣り
# 0049 ¥600
# 0050 42156-0
# 0051 3432
# 0052 シンユリエルミPOS2
# 0053 担当者
# 0054 2155
# 0001 0002 0004 0005 0006 0007 0008 0009 0010 0011 0012 0013 0015 0016 0017 0018 0019 0020 0021 0022 0023 0024 0025 0026 0027 0028 0030 0031 0032 0033 0034 0035 0036 0037 0038 0039 0040 0041 0042 0043 0044 0045 0046 0047 0048 0049 0050 0051 0052 0053 0054

# %%
hi=1
num='0'*(4-len(str(hi)))+str(hi)
hi+=1

# %%
fig, ax = plt.subplots(1,1,figsize=[7,7])
ax.imshow(Image.open(os.path.join(os.path.join(os.path.join('./data', nation_dict[want]), 'img/train'), img_names[i-1])))
for hi in lst:
    points = json_data[img_names[i-1]]['words'][hi]['points']
    poly = patches.Polygon(points, linewidth=1, edgecolor='r', facecolor='none')
    ax.add_patch(poly)
plt.show()
