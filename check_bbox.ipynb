# %%
import os
import json
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
want = 'th'
nation_dict = {
    'vi': 'vietnamese_receipt',
    'th': 'thai_receipt',
    'zh': 'chinese_receipt',
    'ja': 'japanese_receipt',
}

# %%
with open(os.path.join(os.path.join('./data', nation_dict[want]),'ufo/train.json')) as f:
    json_data=json.load(f)['images']
# print(json_data.keys())
img_names = sorted(list(json_data.keys()))
# len(img_names)

# %%
i=32

# %%
fig, ax = plt.subplots(1,2,figsize=(12,7))
print('count =',i,img_names[i])
img = Image.open(os.path.join(os.path.join(os.path.join('./data', nation_dict[want]), 'img/train'), img_names[i]))
img = ImageOps.exif_transpose(img)
ax[0].imshow(img)
ax[1].imshow(img)
for num in json_data[img_names[i]]['words'].keys():
    points = json_data[img_names[i]]['words'][num]['points']
    x1, y1 = points[0]
    x2, y2 = points[2]
    # rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=1, edgecolor='r', facecolor='none')
    poly = patches.Polygon(points, linewidth=1, edgecolor='r', facecolor='none')
    ax[0].add_patch(poly)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[1].set_xticks([])
ax[1].set_yticks([])
plt.show()
i+=1
# Out:
# count = 32 extractor.th.in_house.appen_000315_page0001.jpg

# %%
찾는거 = None
lst=[]
for num in list(json_data[img_names[i-1]]['words']):
    tmp = json_data[img_names[i-1]]['words'][num]['transcription']
    print(num, tmp)
    if tmp == None or len(tmp) == 0:
        continue
    lst.append(num)
if lst:
    print(*lst)
# Out:
# 0001 MSP
# 0002 INTERFOOD,
# 0003 MP
# 0004 จอมทอง
# 0005 (VNA152)
# 0006 TAX#0515562000143
# 0007 (VAT
# 0008 Included)
# 0009 ใบเสร็จรับเงิน/ใบกำกับภาษีอย่างย่อ
# 0010 ID:
# 0011 USR:Khwanr
# 0012 T:001
# 0013 23/03/2024
# 0014 09:23
# 0015 BND:S2403152001-0018365
# 0016 บด-พิเศษC
# 0017 57.00
# 0018 กระดูกเล้ง
# 0019 49.50
# 0020 เอแอนด์พี
# 0021 ลูกชิ้นหมูเอ็น
# 0022 500
# 0023 กรัม
# 0024 45.00
# 0025 V
# 0026 ศรินทิพย์
# 0027 ลูกชิ้นเนื้อ
# 0028 1000
# 0029 กรัม
# 0030 69.00
# 0031 V
# 0032 Total
# 0033 4.00
# 0034 Items
# 0035 220.50
# 0036 Vatable:106.54
# 0037 VAT:7.46
# 0038 Cash
# 0039 1,000.00
# 0040 Change
# 0041 779.50
# 0001 0002 0003 0004 0005 0006 0007 0008 0009 0010 0011 0012 0013 0014 0015 0016 0017 0018 0019 0020 0021 0022 0023 0024 0025 0026 0027 0028 0029 0030 0031 0032 0033 0034 0035 0036 0037 0038 0039 0040 0041

# %%
hi=1
num='0'*(4-len(str(hi)))+str(hi)
hi+=1

# %%
fig, ax = plt.subplots(1,1,figsize=[7,7])
img = Image.open(os.path.join(os.path.join(os.path.join('./data', nation_dict[want]), 'img/train'), img_names[i-1]))
img = ImageOps.exif_transpose(img)
ax.imshow(img)
for hi in lst:
    points = json_data[img_names[i-1]]['words'][hi]['points']
    poly = patches.Polygon(points, linewidth=1, edgecolor='r', facecolor='none')
    ax.add_patch(poly)
plt.show()
