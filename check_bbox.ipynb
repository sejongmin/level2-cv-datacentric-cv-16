# %%
import os
import json
from glob import glob
from pathlib import Path
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
want = 'ja'
nation_dict = {
    'vi': 'vietnamese_receipt',
    'th': 'thai_receipt',
    'zh': 'chinese_receipt',
    'ja': 'japanese_receipt',
}

# %%
with open(os.path.join(os.path.join('./code/data', nation_dict[want]),'ufo/train.json')) as f:
    json_data=json.load(f)['images']
# print(json_data.keys())
img_names = list(json_data.keys())
# len(img_names)

# %%
i=22

# %%
fig, ax = plt.subplots(1,2,figsize=(12,7))
print('i =',i,img_names[i])
ax[0].imshow(Image.open(os.path.join(os.path.join(os.path.join('./code/data', nation_dict[want]), 'img/train'), img_names[i])))
ax[1].imshow(Image.open(os.path.join(os.path.join(os.path.join('./code/data', nation_dict[want]), 'img/train'), img_names[i])))
for num in json_data[img_names[i]]['words'].keys():
    points = json_data[img_names[i]]['words'][num]['points']
    x1, y1 = points[0]
    x2, y2 = points[2]
    rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=1, edgecolor='r', facecolor='none')
    ax[0].add_patch(rect)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[1].set_xticks([])
ax[1].set_yticks([])
plt.show()
i+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[173], line 2
#       1 fig, ax = plt.subplots(1,2,figsize=(12,7))
# ----> 2 print('i =',i,img_names[i])
#       3 ax[0].imshow(Image.open(os.path.join(os.path.join(os.path.join('./code/data', nation_dict[want]), 'img/train'), img_names[i])))
#       4 ax[1].imshow(Image.open(os.path.join(os.path.join(os.path.join('./code/data', nation_dict[want]), 'img/train'), img_names[i])))
#
# IndexError: list index out of range

# %%
for num in list(json_data[img_names[i-1]]['words']):
    tmp = json_data[img_names[i-1]]['words'][num]['transcription']
    print(num, tmp)
# Out:
# 0001 パフレと
# 0002 ��
# 0003 信�
# 0004 居
# 0005 7i
# 0006 セブン-イレブン
# 0007 None
# 0008 渋谷並木橋店
# 0009 東京都渋谷区東1-
# 0010 3
# 0011 2
# 0012 -
# 0013 1
# 0014 2
# 0015 電話
# 0016 :
# 0017 03-3409-7715
# 0018 レジ#2
# 0019 2019年11月
# 0020 26日(火)
# 0021 17:31
# 0022 責711
# 0023 領
# 0024 収
# 0025 書
# 0026 宅急便発払い
# 0027 1,750込
# 0028
# 0029 小
# 0030 計
# 0031 (税込10%)
# 0032 ¥1,750
# 0033 合
# 0034 計
# 0035 ¥1,
# 0036 750
# 0037 (税率10%対象
# 0038 ¥1,750)
# 0039 (内消費税等10%
# 0040 ¥159)
# 0041 お
# 0042 預
# 0043 り
# 0044 ¥10,
# 0045 000
# 0046 お
# 0047 釣
# 0048 ¥8,
# 0049 250
# 0050 お買上明細は上記のとおりです。
# 0051 7
# 0052 アプリでお惣菜を5個買うと
# 0053 7プレミアム
# 0054 100円引き
# 0055 プレゼント!
# 0056 クーポン
# 0057 冷凍食品
# 0058 アプリで参加状況を確認できます
# 0059 ≡
# 0060 None
# 0061 None
# 0062 None
# 0063 <
# 0064 ここを
# 0065 >
# 0066 None
# 0067 None
# 0068 None
# 0069 None
# 0070 None
# 0071 タップ!
# 0072 買えば買うほどお得!
# 0073 DLはこちら
# 0074 ※クーポンは条件達成から24時間以内に記録されます。
# 0075 キャンペーン期間:
# 0076 1
# 0077 1/1(金)~1
# 0078 2/31
# 0079 (火)

# %%
num='0007'

fig, ax = plt.subplots(1,1,figsize=[7,7])
ax.imshow(Image.open(os.path.join(os.path.join(os.path.join('./code/data', nation_dict[want]), 'img/train'), img_names[i-1])))
points = json_data[img_names[i-1]]['words'][num]['points']
x1, y1 = points[0]
x2, y2 = points[2]
rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(rect)
plt.show()
